# %%
from bs4 import BeautifulSoup
import requests

import time
import urllib
import numpy as np
import pandas as pd
import datetime

# %%
'''
从http://news.goldseek.com/COT/获取链接
所有的链接放在list urls中
该部分如无必要，不再运行
'''
basicUrl ="http://news.goldseek.com/COT/"
web_data = requests.get(basicUrl)
soup = BeautifulSoup(web_data.text,"lxml")
gethttps = soup.select("a")
urls=[]
for http in gethttps:
    urls.append(http.get("href"))

for url in urls:
    print url
print len(urls)
# Out:
# http://news.goldseek.com/COT/1503689598.php
# http://news.goldseek.com/COT/1503084718.php
# http://news.goldseek.com/COT/1502480050.php
# http://news.goldseek.com/COT/1501875202.php
# http://news.goldseek.com/COT/1501270346.php
# http://news.goldseek.com/COT/1500665564.php
# http://news.goldseek.com/COT/1500060658.php
# http://news.goldseek.com/COT/1499455834.php
# http://news.goldseek.com/COT/1498851060.php
# http://news.goldseek.com/COT/1498246327.php
# http://news.goldseek.com/COT/1497641609.php
# http://news.goldseek.com/COT/1497037166.php
# http://news.goldseek.com/COT/1496431924.php
# http://news.goldseek.com/COT/1495827026.php
# http://news.goldseek.com/COT/1495222244.php
# http://news.goldseek.com/COT/1494617448.php
# http://news.goldseek.com/COT/1494012653.php
# http://news.goldseek.com/COT/1493407869.php
# http://news.goldseek.com/COT/1492803113.php
# http://news.goldseek.com/COT/1492198252.php
# http://news.goldseek.com/COT/1491593483.php
# ...

# %%
'''
爬取数据作业
1、需要爬取的网页链接放到urls中，可以存放多个
2、解析数据错误的链接会放在error_url中，可以重复执行
'''
urls=error_url

date_list=[]
gold_future_speculator_long=[]
gold_future_speculator_short=[]
gold_future_speculator_spreading=[]
gold_future_commercial_long=[]
gold_future_commerical_short=[]
gold_future_total_long=[]
gold_future_total_short=[]
gold_future_speculator_long_change=[]
gold_future_speculator_short_change=[]
gold_future_speculator_spreading_change=[]
gold_future_commercial_long_change=[]
gold_future_commercial_short_change=[]
gold_future_total_long_change=[]
gold_future_total_short_change=[]

gold_future_and_option_speculator_long=[]
gold_future_and_option_speculator_short=[]
gold_future_and_option_speculator_spreading=[]
gold_future_and_option_commercial_long=[]
gold_future_and_option_commerical_short=[]
gold_future_and_option_total_long=[]
gold_future_and_option_total_short=[]
gold_future_and_option_speculator_long_change=[]
gold_future_and_option_speculator_short_change=[]
gold_future_and_option_speculator_spreading_change=[]
gold_future_and_option_commercial_long_change=[]
gold_future_and_option_commercial_short_change=[]
gold_future_and_option_total_long_change=[]
gold_future_and_option_total_short_change=[]

silver_future_speculator_long=[]
silver_future_speculator_short=[]
silver_future_speculator_spreading=[]
silver_future_commercial_long=[]
silver_future_commerical_short=[]
silver_future_total_long=[]
silver_future_total_short=[]

silver_future_and_option_speculator_long=[]
silver_future_and_option_speculator_short=[]
silver_future_and_option_speculator_spreading=[]
silver_future_and_option_commercial_long=[]
silver_future_and_option_commerical_short=[]
silver_future_and_option_total_long=[]
silver_future_and_option_total_short=[]

dollarIndex_future_speculator_long=[]
dollarIndex_future_speculator_short=[]
dollarIndex_future_speculator_spreading=[]
dollarIndex_future_commercial_long=[]
dollarIndex_future_commerical_short=[]
dollarIndex_future_total_long=[]
dollarIndex_future_total_short=[]

dollarIndex_future_and_option_speculator_long=[]
dollarIndex_future_and_option_speculator_short=[]
dollarIndex_future_and_option_speculator_spreading=[]
dollarIndex_future_and_option_commercial_long=[]
dollarIndex_future_and_option_commerical_short=[]
dollarIndex_future_and_option_total_long=[]
dollarIndex_future_and_option_total_short=[]

need_to_getdata_urls=['http://news.goldseek.com/COT/1503689598.php']
error_url=[]
for url in need_to_getdata_urls:
    #tmpurl="http://news.goldseek.com/COT/1503084718.php"
    try:
        web_data1=requests.get(url)
    except :
        try:
            web_data1=requests.get(url)
        except :
            print "get requests error:%s"%(url)
            error_url.append(url)
            continue
    soup1 = BeautifulSoup(web_data1.text,"lxml")
    context_data=soup1.select("body > table ")
    #print context_data
    for table_context in context_data:
        if len(table_context)==0:
            continue
        else:
            tables=table_context.find_all("span", style="FONT-FAMILY: 'Verdana','sans-serif'; FONT-SIZE: 10pt; mso-bidi-font-family: Arial; mso-fareast-font-family: 'Times New Roman'")
            if len(tables)==0:
                tables=table_context.find_all("span", style="FONT-SIZE: 10pt; FONT-FAMILY: 'Verdana','sans-serif'; mso-bidi-font-family: Arial; mso-fareast-font-family: 'Times New Roman'")
            if len(tables)==0:
                tables=table_context.find_all("span", style="FONT-FAMILY: 'Verdana','sans-serif'; FONT-SIZE: 10pt; mso-fareast-font-family: 'Times New Roman'; mso-bidi-font-family: Arial")
                
            dates_context=table_context.find_all("font", face="Verdana, Arial, Helvetica, sans-serif")
    table_string=[]
    date_string=[]
    #print tables
    for data in tables:
        table_string.append(data.get_text())
    for date_context in dates_context:
        date_string.append(date_context.get_text())
    #print table_string
    #print date_string
    if len(table_string)==0 and len(date_string)==0:
        print "this url ==[]:%s"%(url)
        error_url.append(url)
        continue
    
    if len(table_string)<139:
        print "this url pardise error:%s,len:%d"%(url,len(table_string))
        error_url.append(url)
        continue
    
    title="COT Gold, Silver and US Dollar Index Report"
    for i in date_string:
        if i[0:len(title)]==title:
            #print i[46:]
            date = datetime.datetime.strptime(i[46:],"%B %d, %Y")
    date_list.append(date)
    gold_future_speculator_long.append(table_string[7])
    gold_future_speculator_short.append(table_string[8])
    gold_future_speculator_spreading.append(table_string[9])
    gold_future_commercial_long.append(table_string[10])
    gold_future_commerical_short.append(table_string[11])
    gold_future_total_long.append(table_string[12])
    gold_future_total_short.append(table_string[13])
    gold_future_speculator_long_change.append(table_string[15])
    gold_future_speculator_short_change.append(table_string[16])
    gold_future_speculator_spreading_change.append(table_string[17])
    gold_future_commercial_long_change.append(table_string[18])
    gold_future_commercial_short_change.append(table_string[19])
    gold_future_total_long_change.append(table_string[20])
    gold_future_total_short_change.append(table_string[21])

    gold_future_and_option_speculator_long.append(table_string[40])
    gold_future_and_option_speculator_short.append(table_string[41])
    gold_future_and_option_speculator_spreading.append(table_string[42])
    gold_future_and_option_commercial_long.append(table_string[43])
    gold_future_and_option_commerical_short.append(table_string[44])
    gold_future_and_option_total_long.append(table_string[45])
    gold_future_and_option_total_short.append(table_string[46])
    gold_future_and_option_speculator_long_change.append(table_string[48])
    gold_future_and_option_speculator_short_change.append(table_string[49])
    gold_future_and_option_speculator_spreading_change.append(table_string[50])
    gold_future_and_option_commercial_long_change.append(table_string[51])
    gold_future_and_option_commercial_short_change.append(table_string[52])
    gold_future_and_option_total_long_change.append(table_string[53])
    gold_future_and_option_total_short_change.append(table_string[54])

    silver_future_speculator_long.append(table_string[71])
    silver_future_speculator_short.append(table_string[72])
    silver_future_speculator_spreading.append(table_string[73])
    silver_future_commercial_long.append(table_string[74])
    silver_future_commerical_short.append(table_string[75])
    silver_future_total_long.append(table_string[83])
    silver_future_total_short.append(table_string[84])

    silver_future_and_option_speculator_long.append(table_string[90])
    silver_future_and_option_speculator_short.append(table_string[91])
    silver_future_and_option_speculator_spreading.append(table_string[92])
    silver_future_and_option_commercial_long.append(table_string[93])
    silver_future_and_option_commerical_short.append(table_string[94])
    silver_future_and_option_total_long.append(table_string[102])
    silver_future_and_option_total_short.append(table_string[103])

    dollarIndex_future_speculator_long.append(table_string[111])
    dollarIndex_future_speculator_short.append(table_string[112])
    dollarIndex_future_speculator_spreading.append(table_string[113])
    dollarIndex_future_commercial_long.append(table_string[114])
    dollarIndex_future_commerical_short.append(table_string[115])
    dollarIndex_future_total_long.append(table_string[116])
    dollarIndex_future_total_short.append(table_string[117])

    dollarIndex_future_and_option_speculator_long.append(table_string[133])
    dollarIndex_future_and_option_speculator_short.append(table_string[134])
    dollarIndex_future_and_option_speculator_spreading.append(table_string[135])
    dollarIndex_future_and_option_commercial_long.append(table_string[136])
    dollarIndex_future_and_option_commerical_short.append(table_string[137])
    dollarIndex_future_and_option_total_long.append(table_string[138])
    dollarIndex_future_and_option_total_short.append(table_string[139])

gold_future_table={
    "date":date_list,
    "speculator(long)":gold_future_speculator_long,
    "speculator(short)":gold_future_speculator_short,
    "speculator(spreading)":gold_future_speculator_spreading,
    "commercial(long)":gold_future_commercial_long,
    "commercial(short)":gold_future_commerical_short,
    "total(long)":gold_future_total_long,
    "total(short)":gold_future_total_short,
    "speculator(long)_change":gold_future_speculator_long_change,
    "speculator(short)_change":gold_future_speculator_short_change,
    "speculator(spreading)_change":gold_future_speculator_spreading_change,
    "commercial(long)_change":gold_future_commercial_long_change,
    "commercial(short)_change":gold_future_commercial_long_change,
    "total(long)_change":gold_future_total_long_change,
    "total(short)_change":gold_future_total_short_change   
}

gold_future_and_option_table={
    "date":date_list,
    "speculator(long)":gold_future_and_option_speculator_long,
    "speculator(short)":gold_future_and_option_speculator_short,
    "speculator(spreading)":gold_future_and_option_speculator_spreading,
    "commercial(long)":gold_future_and_option_commercial_long,
    "commercial(short)":gold_future_and_option_commerical_short,
    "total(long)":gold_future_and_option_total_long,
    "total(short)":gold_future_and_option_total_short,
    "speculator(long)_change":gold_future_and_option_speculator_long_change,
    "speculator(short)_change":gold_future_and_option_speculator_short_change,
    "speculator(spreading)_change":gold_future_and_option_speculator_spreading_change,
    "commercial(long)_change":gold_future_and_option_commercial_long_change,
    "commercial(short)_change":gold_future_and_option_commercial_short_change,
    "total(long)_change":gold_future_and_option_total_long_change,
    "total(short)_change":gold_future_and_option_total_short_change
}
silver_future_table={
    "date":date_list,
    "speculator(long)":silver_future_speculator_long,
    "speculator(short)":silver_future_speculator_short,
    "speculator(spreading)":silver_future_speculator_spreading,
    "commercial(long)":silver_future_commercial_long,
    "commercial(short)":silver_future_commerical_short,
    "total(long)":silver_future_total_long,
    "total(short)":silver_future_total_short
    
}
silver_future_and_option_table={
    "date":date_list,
    "speculator(long)":silver_future_and_option_speculator_long,
    "speculator(short)":silver_future_and_option_speculator_short,
    "speculator(spreading)":silver_future_and_option_speculator_spreading,
    "commercial(long)":silver_future_and_option_commercial_long,
    "commercial(short)":silver_future_and_option_commerical_short,
    "total(long)":silver_future_and_option_total_long,
    "total(short)":silver_future_and_option_total_short
    
}
dollarIndex_future_table={
    "date":date_list,
    "speculator(long)":dollarIndex_future_speculator_long,
    "speculator(short)":dollarIndex_future_speculator_short,
    "speculator(spreading)":dollarIndex_future_speculator_spreading,
    "commercial(long)":dollarIndex_future_commercial_long,
    "commercial(short)":dollarIndex_future_commerical_short,
    "total(long)":dollarIndex_future_total_long,
    "total(short)":dollarIndex_future_total_short
    
}
dollarIndex_future_and_option_table={
    "date":date_list,
    "speculator(long)":dollarIndex_future_and_option_speculator_long,
    "speculator(short)":dollarIndex_future_and_option_speculator_short,
    "speculator(spreading)":dollarIndex_future_and_option_speculator_spreading,
    "commercial(long)":dollarIndex_future_and_option_commercial_long,
    "commercial(short)":dollarIndex_future_and_option_commerical_short,
    "total(long)":dollarIndex_future_and_option_total_long,
    "total(short)":dollarIndex_future_and_option_total_short
    
}
goldFutureTable = pd.DataFrame(gold_future_table,columns=["date","speculator(long)","speculator(short)","speculator(spreading)",\
                                                         "commercial(long)","commercial(short)","total(long)","total(short)",\
                                                         "speculator(long)_change","speculator(short)_change","speculator(spreading)_change",\
                                                         "commercial(long)_change","commercial(short)_change","total(long)_change",\
                                                         "total(short)_change"])

goldFutureOptionTable = pd.DataFrame(gold_future_and_option_table,columns=["date","speculator(long)","speculator(short)","speculator(spreading)",\
                                                         "commercial(long)","commercial(short)","total(long)","total(short)",\
                                                         "speculator(long)_change","speculator(short)_change","speculator(spreading)_change",\
                                                         "commercial(long)_change","commercial(short)_change","total(long)_change",\
                                                         "total(short)_change"])

silverFutureTable = pd.DataFrame(silver_future_table,columns=["date","speculator(long)","speculator(short)","speculator(spreading)",\
                                                         "commercial(long)","commercial(short)","total(long)","total(short)"])

silverFutureOptionTable = pd.DataFrame(silver_future_and_option_table,columns=["date","speculator(long)","speculator(short)",\
                                                                               "speculator(spreading)","commercial(long)",\
                                                                               "commercial(short)","total(long)","total(short)"])                                                                  
dollarIndexFutureTable = pd.DataFrame(dollarIndex_future_table,columns=["date","speculator(long)","speculator(short)","speculator(spreading)",\
                                                         "commercial(long)","commercial(short)","total(long)","total(short)"])

dollarIndexFutureOptionTable = pd.DataFrame(dollarIndex_future_and_option_table,columns=["date","speculator(long)","speculator(short)",\
                                                                                         "speculator(spreading)","commercial(long)","commercial(short)",\
                                                                                         "total(long)","total(short)"])
goldFutureTable.to_csv("C:\\pythoncoding\\data\\gold\\goldFutureTable.csv",mode='a', header=None)
goldFutureOptionTable.to_csv("C:\\pythoncoding\\data\\gold\\goldFutureOptionTable.csv",mode='a', header=None)
silverFutureTable.to_csv("C:\\pythoncoding\\data\\gold\\silverFutureTable.csv",mode='a', header=None)
silverFutureOptionTable.to_csv("C:\\pythoncoding\\data\\gold\\silverFutureOptionTable.csv",mode='a', header=None)
dollarIndexFutureTable.to_csv("C:\\pythoncoding\\data\\gold\\dollarIndexFutureTable.csv",mode='a', header=None)
dollarIndexFutureOptionTable.to_csv("C:\\pythoncoding\\data\\gold\\dollarIndexFutureOptionTable.csv",mode='a', header=None)
print error_url
# Out:
# this url pardise error:http://news.goldseek.com/COT/1503689598.php,len:0
# ['http://news.goldseek.com/COT/1503689598.php']

# %%
#研究测试用
"http://news.goldseek.com/COT/1502480050.php"

gold_future_speculator_long=[]
gold_future_speculator_short=[]
gold_future_speculator_spreading=[]
gold_future_commercial_long=[]
gold_future_commerical_short=[]
gold_future_total_long=[]
gold_future_total_short=[]
gold_future_speculator_long_change=[]
gold_future_speculator_short_change=[]
gold_future_speculator_spreading_change=[]
gold_future_commercial_long_change=[]
gold_future_commercial_short_change=[]
gold_future_total_long_change=[]
gold_future_total_short_change=[]

gold_future_and_option_speculator_long=[]
gold_future_and_option_speculator_short=[]
gold_future_and_option_speculator_spreading=[]
gold_future_and_option_commercial_long=[]
gold_future_and_option_commerical_short=[]
gold_future_and_option_total_long=[]
gold_future_and_option_total_short=[]
gold_future_and_option_speculator_long_change=[]
gold_future_and_option_speculator_short_change=[]
gold_future_and_option_speculator_spreading_change=[]
gold_future_and_option_commercial_long_change=[]
gold_future_and_option_commercial_short_change=[]
gold_future_and_option_total_long_change=[]
gold_future_and_option_total_short_change=[]

silver_future_speculator_long=[]
silver_future_speculator_short=[]
silver_future_speculator_spreading=[]
silver_future_commercial_long=[]
silver_future_commerical_short=[]
silver_future_total_long=[]
silver_future_total_short=[]

silver_future_and_option_speculator_long=[]
silver_future_and_option_speculator_short=[]
silver_future_and_option_speculator_spreading=[]
silver_future_and_option_commercial_long=[]
silver_future_and_option_commerical_short=[]
silver_future_and_option_total_long=[]
silver_future_and_option_total_short=[]

dollarIndex_future_speculator_long=[]
dollarIndex_future_speculator_short=[]
dollarIndex_future_speculator_spreading=[]
dollarIndex_future_commercial_long=[]
dollarIndex_future_commerical_short=[]
dollarIndex_future_total_long=[]
dollarIndex_future_total_short=[]

dollarIndex_future_and_option_speculator_long=[]
dollarIndex_future_and_option_speculator_short=[]
dollarIndex_future_and_option_speculator_spreading=[]
dollarIndex_future_and_option_commercial_long=[]
dollarIndex_future_and_option_commerical_short=[]
dollarIndex_future_and_option_total_long=[]
dollarIndex_future_and_option_total_short=[]

urls=['http://news.goldseek.com/COT/1503689598.php']
error_url=[]
for url in urls:
    #tmpurl="http://news.goldseek.com/COT/1503084718.php"
    try:
        web_data1=requests.get(url)
    except :
        try:
            web_data1=requests.get(url)
        except :
            print "get requests error:%s"%(url)
            error_url.append(url)
            continue
    soup1 = BeautifulSoup(web_data1.text,"lxml")
    context_data=soup1.select("body > table ")
    print context_data
# Out:
# [<table background="http://www.goldseek.com/images/back.PNG" border="0" cellpadding="0" cellspacing="0" width="100%">\n<tr>\n<td height="160" rowspan="2" valign="top" width="200"><a href="http://www.goldseek.com/"><img align="top" border="0" height="160" heigth="160" src="http://www.goldseek.com/images/gslogo.jpg" width="160"/></a></td>\n<td align="center" colspan="2" valign="middle">\n</td>\n</tr>\n<tr>\n<td valign="top">\n<div align="center">\n<font color="#FFFFFF" face="Verdana, Arial, Helvetica, sans-serif" size="1"><b>\n<script type="text/javascript">function addBookmark(title,url) {if (window.sidebar) { window.sidebar.addPanel(title, url,""); } else if( document.all ) {window.external.AddFavorite( url, title);} else if( window.opera && window.print ) {return true;}}</script>\xa0<a href="http://www.goldseek.com/advertise.php"><font color="#FFFFFF">Advertise</font></a>\xa0|\xa0<a href="#" onmousedown="addBookmark('GoldSeek.com','http://www.GoldSeek.com/')"><font color="#FFCC00">B
# ...

# %%
#print context_data
for table_context in context_data:
    #print "=========================================="
    #print table_context
    #print "=========================================="
    if len(table_context)==0:
        continue
    else:
        tables=table_context.find_all("font", size="2")
        print tables
# Out:
# []
# [<font size="2"><font face="Verdana, Arial, Helvetica, sans-serif"><b><a class="menu" href="http://commentary.goldseek.com">Commentary</a>\xa0:\xa0<a class="menu" href="http://www.GoldReview.com/">Gold\xa0Review</a>\xa0:\xa0<a class="menu" href="http://markets.goldseek.com">Markets</a>\xa0:\xa0<a class="menu" href="http://news.goldseek.com">News\xa0Wire</a>\xa0:\xa0<a class="menu" href="http://quote.goldseek.com">Quotes</a>\xa0:\xa0<a class="menu" href="http://www.SilverSeek.com">Silver</a>\xa0:\xa0<a class="menu" href="http://stocks.goldseek.com/">Stocks</a>\xa0-\xa0<a class="menu" href="http://www.GoldSeek.com/">Main Page</a>\xa0<font color="#000033" face="Verdana, Arial, Helvetica, sans-serif" size="1"></font></b></font></font>]
# ...

# %%
url="https://wallstreetcn.com/markets/commodities"
web_data1=requests.get(url)        
soup1 = BeautifulSoup(web_data1.text,"lxml")
context_data=soup1.select("app > div > main > div > div.wrapper > div > div > div.left-area > div > div > div.list ")
print soup1
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="" data-vue-meta-server-rendered=""> <head> <meta charset="utf-8"/> <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/> <meta content="webkit" name="renderer"/> <link href="https://static-alpha.wallstreetcn.com/wscn/favicon.d4bb8b4dbefdc9c2584dbfe140871554.png" rel="icon" type="image/png"/> <link href="https://static-alpha.wallstreetcn.com/wscn/client.1b7e50c8f9b3395401ee83943a84bc4a.css" rel="stylesheet"/>
# <meta content="华尔街见闻实时行情为您提供最快速的行情服务，包括：外汇、商品、股票、指数、债券等，帮助您第一时间了解全球市场" data-hid="description" data-vue-meta="true" name="description"/><meta content="外汇，商品，黄金，布伦特原油，WTI，白银，国债，全球市场，行情，A股，数据" data-hid="keywords" data-vue-meta="true" name="keywords"/>
# <title data-vue-meta="true">实时行情 - 华尔街见闻</title>
# </head> <body data-vue-meta="">
# ...
